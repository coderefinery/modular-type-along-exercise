# %% [markdown]
# # Weather Data Analysis and Visualization Mini-Project (Pre-task)
#
# This pre-task prepares you for a modular coding course.

# %% [markdown]
# ## Dataset
# The dataset contains hourly weather measurements for the observation station “Vantaa Helsinki-Vantaan lentoasema” (Helsinki airport) during 2024.
#
# **File**: `weather_data.csv`

# %%
import pandas as pd
df = pd.read_csv("weather_data.csv")

# %%
df.head()
# Out:
#    year  month  day   time  air_temperature  precipitation
# 0  2024      1    1  00:00            -16.1            0.0
# 1  2024      1    1  01:00            -16.1            0.0
# 2  2024      1    1  02:00            -16.0            0.0
# 3  2024      1    1  03:00            -15.9            0.0
# 4  2024      1    1  04:00            -16.1            0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8739 entries, 0 to 8738
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             8739 non-null   int64
#  1   month            8739 non-null   int64
#  2   day              8739 non-null   int64
#  3   time             8739 non-null   object
#  4   air_temperature  8739 non-null   float64
#  5   precipitation    8739 non-null   float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 409.8+ KB

# %% [markdown]
# ## Core tasks
# Explore hourly weather data and produce monthly plots and simple stats.
#
# **What you will practice**: Working with data, improving code provided bellow, and creating visualizations
#
# Some concepts to consider:
# - How can you make the code more readible and easy to navigate?
# - What are good ways to structure code for reuse?
# - How can you make your analysis clear and reproducible?
# - How can you make the code portable?
# - How can you structure the code to enable parallel processing or integration into larger workflows,e.g. snakemake?
# - What validation might be helpful?
# - Are there any other good practices you can think of?
#
#
# **Note**:
# - Feel free to use this notebook or create separate Python scripts if you prefer.
# - You’re welcome to try the strategy on your own data, or share a notebook/script using weather data from your location in your favorite programming language.

# %%
from matplotlib import pyplot as plt

# month to process
month = 1

#filter for month=month
data = df[df['month'] == month].reset_index(drop=True)  # Filter month only and reindex

temperatures = data["air_temperature"]
precipitation = data["precipitation"]

num_measurements = len(precipitation)

# compute statistics
temp_mean = sum(temperatures) / num_measurements
precip_mean = sum(precipitation) / num_measurements

# plot temperature
plt.figure()
plt.plot(temperatures, "r-")
plt.axhline(y=temp_mean, color="r", linestyle="--")
plt.savefig(f"month-{month}_air_temperature.png")
plt.show()
plt.close()

# plot precipitation
plt.figure()
plt.plot(precipitation, "b-")
plt.axhline(y=precip_mean, color="b", linestyle="--")
plt.savefig(f"month-{month}_precipitation.png")
plt.show()
plt.close()
